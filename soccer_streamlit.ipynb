# %%
import pandas as pd
import streamlit as st
import matplotlib.pyplot as plt

# %%
soccer_df = pd.read_csv('soccer_df.csv')

# %%
soccer_df
# Out:
#      year  month  day          home_team          away_team  home_score  \
# 0    2018      8   10  Manchester United          Leicester         2.0
# 1    2018      8   19           Brighton  Manchester United         3.0
# 2    2018      8   27  Manchester United          Tottenham         0.0
# 3    2018      9    2            Burnley  Manchester United         0.0
# 4    2018      9   15            Watford  Manchester United         1.0
# ..    ...    ...  ...                ...                ...         ...
# 234  2024     10    6        Aston Villa  Manchester United         0.0
# 235  2024     10   19  Manchester United          Brentford         2.0
# 236  2024     10   27           West Ham  Manchester United         2.0
# 237  2024     11    3  Manchester United            Chelsea         1.0
# 238  2024     11   10  Manchester United          Leicester         3.0
#
#      away_score Ball Possession  Total Shots  Shots on Goal  ...  Offsides  \
# ...
